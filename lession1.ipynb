# %%
import torch

# %%
x=torch.rand(4,4)
x
# Out:
# tensor([[0.9113, 0.8242, 0.2908, 0.5935],
#         [0.1706, 0.8297, 0.9764, 0.5559],
#         [0.2411, 0.2453, 0.2323, 0.3192],
#         [0.0872, 0.1897, 0.3055, 0.8685]])

# %%
x[1:4,1]
# Out:
# tensor([0.8297, 0.2453, 0.1897])

# %%
y=x.numpy()
y
y.shape
# Out:
# (4, 4)

# %%
y=x.view(-1,2)

# %%
y.shape
# Out:
# torch.Size([8, 2])
