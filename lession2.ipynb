# %%
import torch

# %%
x=torch.tensor(2., requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y=3*x + 2*x
y
# Out:
# tensor(10., grad_fn=<AddBackward0>)

# %%
y.backward()
x.grad #dy/dx
# Out:
# tensor(5.)

# %%
x
# Out:
# tensor(2., requires_grad=True)
